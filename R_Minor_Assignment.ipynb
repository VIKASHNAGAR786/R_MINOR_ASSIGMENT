# %% [markdown]
# # R Programming - Minor Assignment
# **Name:** Vikas Nagar
# **Subject:** R Programming
# **Semester:** II
# **Date:** March 2026

# %% [markdown]
# ---
# ## Question 1
# **Write a R program to concatenate a vector.**

# %%
# Method 1: Concatenate two numeric vectors using c()
v1 <- c(1, 2, 3, 4, 5)
v2 <- c(6, 7, 8, 9, 10)

result <- c(v1, v2)
cat("Vector 1:", v1, "\n")
cat("Vector 2:", v2, "\n")
cat("Concatenated Vector:", result, "\n\n")

# Method 2: Concatenate character vectors
fruits1 <- c("Apple", "Banana", "Cherry")
fruits2 <- c("Date", "Elderberry", "Fig")

combined_fruits <- c(fruits1, fruits2)
cat("Fruits Vector 1:", fruits1, "\n")
cat("Fruits Vector 2:", fruits2, "\n")
cat("Concatenated Fruits:", combined_fruits, "\n\n")

# Method 3: Using append() function
v3 <- c(10, 20, 30)
v4 <- c(40, 50, 60)

appended_result <- append(v3, v4)
cat("Using append():", appended_result, "\n")

# %% [markdown]
# ---
# ## Question 2
# **Write a R program to access the last value in a given vector.**

# %%
# Sample vector
v <- c(10, 20, 30, 40, 50, 60, 70)
cat("Vector:", v, "\n\n")

# Method 1: Using length() - most common way
last_value_1 <- v[length(v)]
cat("Method 1 - Using length():", last_value_1, "\n")

# Method 2: Using tail() function
last_value_2 <- tail(v, 1)
cat("Method 2 - Using tail():", last_value_2, "\n")

# Method 3: Using rev()
last_value_3 <- rev(v)[1]
cat("Method 3 - Using rev()[1]:", last_value_3, "\n\n")

# Another example with character vector
names_vec <- c("Alice", "Bob", "Charlie", "Diana", "Eve")
cat("Character Vector:", names_vec, "\n")
cat("Last value:", names_vec[length(names_vec)], "\n")

# %% [markdown]
# ---
# ## Question 3
# **Write a R program to find common elements from multiple vectors.**

# %%
# Define multiple vectors
v1 <- c(1, 2, 3, 4, 5, 6)
v2 <- c(3, 4, 5, 6, 7, 8)
v3 <- c(4, 5, 6, 9, 10, 11)

cat("Vector 1:", v1, "\n")
cat("Vector 2:", v2, "\n")
cat("Vector 3:", v3, "\n\n")

# Method 1: Common elements between two vectors using intersect()
common_v1_v2 <- intersect(v1, v2)
cat("Common elements between V1 and V2:", common_v1_v2, "\n")

# Method 2: Common elements among all three vectors using Reduce()
common_all <- Reduce(intersect, list(v1, v2, v3))
cat("Common elements among all three vectors:", common_all, "\n\n")

# Example with character vectors
fruits1 <- c("Apple", "Banana", "Cherry", "Date", "Elderberry")
fruits2 <- c("Banana", "Cherry", "Fig", "Grape")
fruits3 <- c("Cherry", "Banana", "Kiwi", "Mango")

cat("Fruits Vector 1:", fruits1, "\n")
cat("Fruits Vector 2:", fruits2, "\n")
cat("Fruits Vector 3:", fruits3, "\n")

common_fruits_12 <- intersect(fruits1, fruits2)
cat("\nCommon fruits in V1 & V2:", common_fruits_12, "\n")

common_fruits_all <- Reduce(intersect, list(fruits1, fruits2, fruits3))
cat("Common fruits in all 3 vectors:", common_fruits_all, "\n")

# %% [markdown]
# ---
# ## Question 4
# **Create a vector that repeats the values "A", "B" ten times (e.g., "A", "B", "A", "B"...).**

# %%
# Method 1: Using rep() with times - alternating A, B repeated 10 times
repeated_vec <- rep(c("A", "B"), times = 10)
cat("Repeated Vector (A, B x10):\n")
print(repeated_vec)
cat("\nLength of vector:", length(repeated_vec), "\n\n")

# Method 2: Using rep() with 'each' - each element repeated 10 times
each_vec <- rep(c("A", "B"), each = 10)
cat("Vector with each element repeated 10 times:\n")
print(each_vec)
cat("\nLength of vector:", length(each_vec), "\n")

# %% [markdown]
# ---
# ## Question 5
# **What function would you use to check the number of elements in a vector?**

# %%
# The function used to check the number of elements in a vector is: length()

# Example 1: Numeric vector
num_vec <- c(10, 20, 30, 40, 50)
cat("Numeric Vector:", num_vec, "\n")
cat("Number of elements:", length(num_vec), "\n\n")

# Example 2: Character vector
char_vec <- c("Apple", "Banana", "Cherry", "Date")
cat("Character Vector:", char_vec, "\n")
cat("Number of elements:", length(char_vec), "\n\n")

# Example 3: Logical vector
log_vec <- c(TRUE, FALSE, TRUE, TRUE, FALSE, TRUE)
cat("Logical Vector:", log_vec, "\n")
cat("Number of elements:", length(log_vec), "\n\n")

# Example 4: Empty vector
empty_vec <- c()
cat("Empty Vector: (none)\n")
cat("Number of elements:", length(empty_vec), "\n\n")

cat("=== ANSWER ===\n")
cat("Function used  : length()\n")
cat("Syntax         : length(vector_name)\n")
cat("Returns        : Integer - count of elements in the vector\n")

# %% [markdown]
# ---
# ## Question 6
# **You have a list of product stock levels. Some items are out of stock (0) or have errors (negative numbers).**
# `stock <- c(50, 0, 100, -5, 20, 0, 35)`
#
# - **(a)** Create a logical filter to identify valid stock levels (values strictly greater than 0).
# - **(b)** Use this filter to create a new vector `valid_stock` containing only the positive numbers.
# - **(c)** Calculate the median of the valid stock.

# %%
stock <- c(50, 0, 100, -5, 20, 0, 35)
cat("Original stock levels:", stock, "\n\n")

# Part a: Logical filter - TRUE where stock > 0
valid_filter <- stock > 0
cat("Part a - Logical filter (stock > 0):\n")
print(valid_filter)
cat("\n")

# Part b: Create valid_stock vector using the filter
valid_stock <- stock[valid_filter]
cat("Part b - valid_stock (positive values only):", valid_stock, "\n\n")

# Part c: Median of valid stock
median_valid <- median(valid_stock)
cat("Part c - Median of valid stock:", median_valid, "\n")

# %% [markdown]
# ---
# ## Question 7
# **You have temperature data from a sensor that occasionally fails (producing NA).**
# `temps <- c(22.5, 23.0, NA, 21.5, 24.0, NA, 22.0)`
#
# - **(a)** Check which elements are missing using the `is.na()` function.
# - **(b)** Calculate the average (mean) temperature.

# %%
temps <- c(22.5, 23.0, NA, 21.5, 24.0, NA, 22.0)
cat("Temperature data:", temps, "\n\n")

# Part a: Check which elements are NA
missing_check <- is.na(temps)
cat("Part a - Which elements are NA (is.na()):\n")
print(missing_check)
cat("\nPosition(s) with NA:", which(missing_check), "\n\n")

# Part b: Mean temperature ignoring NAs
avg_temp <- mean(temps, na.rm = TRUE)
cat("Part b - Average (mean) temperature (ignoring NAs):", avg_temp, "°C\n\n")

# Bonus info
cat("Total NA values:", sum(missing_check), "\n")
cat("Valid readings :", sum(!missing_check), "\n")

# %% [markdown]
# ---
# ## Question 8
# **Following are grades of students:**
# `grades <- c(85, 92, 78, 88, 95)`
# **The professor decides to add a "curve" to the grades.**
#
# - **(a)** Add 5 points to every student's grade.
# - **(b)** After adding the points, cap the maximum score at 100.

# %%
grades <- c(85, 92, 78, 88, 95)
cat("Original grades:", grades, "\n\n")

# Part a: Add 5 points to every grade
curved_grades <- grades + 5
cat("Part a - Grades after adding 5 points:", curved_grades, "\n\n")

# Part b: Cap at 100 using pmin()
final_grades <- pmin(curved_grades, 100)
cat("Part b - Final grades (capped at 100):", final_grades, "\n\n")

# Summary table
cat("=== Grade Summary ===\n")
cat(sprintf("%-10s %-15s %-15s\n", "Student", "Original", "Final(+5,cap100)"))
cat(strrep("-", 45), "\n")
for (i in seq_along(grades)) {
  cat(sprintf("%-10s %-15d %-15d\n", paste0("S", i), grades[i], final_grades[i]))
}
cat("\nClass average after curve:", mean(final_grades), "\n")

# %% [markdown]
# ---
# ## Question 9
# **Create a 3x3 array representing a marks sheet for 3 students across 3 subjects. Then:**
#
# - **(a)** Calculate the total marks of each student (row sum)
# - **(b)** Calculate the class average per subject (column mean)
# - **(c)** Find the student with the highest total

# %%
# Create a 3x3 matrix (marks sheet)
marks_data <- c(85, 90, 78,
                72, 88, 95,
                91, 76, 83)

marks_sheet <- matrix(marks_data, nrow = 3, ncol = 3, byrow = TRUE,
                      dimnames = list(
                        c("Student1", "Student2", "Student3"),
                        c("Math", "Science", "English")
                      ))

cat("=== Marks Sheet ===\n")
print(marks_sheet)
cat("\n")

# Part a: Total marks of each student (row sums)
student_totals <- rowSums(marks_sheet)
cat("Part a - Total marks of each student:\n")
print(student_totals)
cat("\n")

# Part b: Class average per subject (column means)
subject_averages <- colMeans(marks_sheet)
cat("Part b - Class average per subject:\n")
print(subject_averages)
cat("\n")

# Part c: Student with the highest total
top_student <- names(which.max(student_totals))
cat("Part c - Student with the highest total:", top_student,
    "with", max(student_totals), "marks\n")

# %% [markdown]
# ---
# ## Question 10
# **Create a function in R that prints square of first five prime numbers.**

# %%
# Helper function to check if a number is prime
is_prime <- function(n) {
  if (n < 2) return(FALSE)
  if (n == 2) return(TRUE)
  if (n %% 2 == 0) return(FALSE)
  for (i in 3:floor(sqrt(n))) {
    if (n %% i == 0) return(FALSE)
  }
  return(TRUE)
}

# Main function: prints squares of the first five prime numbers
print_squares_of_first_five_primes <- function() {
  primes <- c()
  num <- 2

  while (length(primes) < 5) {
    if (is_prime(num)) {
      primes <- c(primes, num)
    }
    num <- num + 1
  }

  cat("First five prime numbers:", primes, "\n\n")
  cat("Squares of first five prime numbers:\n")
  for (p in primes) {
    cat(sprintf("  %d^2 = %d\n", p, p^2))
  }
}

# Call the function
print_squares_of_first_five_primes()

# %% [markdown]
# ---
# ## Question 11
# **Use the built-in `airquality` dataset in R and perform the following tasks:**
#
# - **(a)** Load and inspect the dataset; count missing values per column
# - **(b)** Base R summaries per month (mean Ozone, max Wind, min/mean/max Temp)
# - **(c)** Repeat summaries using `dplyr`
# - **(d)** Add `Temp_category` column (Cool / Mild / Hot)
# - **(e)** Count days per temperature category per month
# - **(f)** Clean summary table per month
# - **(g)** Add `cumulative_heat` column

# %%
# ============================================================
# Part a: Load dataset and inspect structure + missing values
# ============================================================
data("airquality")

cat("=== Part a: Structure of airquality dataset ===\n")
str(airquality)

cat("\nFirst 6 rows:\n")
print(head(airquality))

cat("\nMissing values in each column:\n")
print(colSums(is.na(airquality)))

# %%
# ============================================================
# Part b: Base R summaries per month
# ============================================================
cat("=== Part b: Base R Summaries per Month ===\n")

# i. Mean Ozone concentration (ignore NAs)
cat("\ni. Mean Ozone per Month:\n")
mean_ozone <- tapply(airquality$Ozone, airquality$Month, mean, na.rm = TRUE)
print(round(mean_ozone, 1))

# ii. Maximum Wind speed per month
cat("\nii. Maximum Wind Speed per Month:\n")
max_wind <- tapply(airquality$Wind, airquality$Month, max, na.rm = TRUE)
print(max_wind)

# iii. Min, Mean, Max Temperature per month
cat("\niii. Temperature Statistics per Month:\n")
temp_min  <- tapply(airquality$Temp, airquality$Month, min,  na.rm = TRUE)
temp_mean <- tapply(airquality$Temp, airquality$Month, mean, na.rm = TRUE)
temp_max  <- tapply(airquality$Temp, airquality$Month, max,  na.rm = TRUE)

temp_summary <- data.frame(
  Month     = names(temp_min),
  Min_Temp  = temp_min,
  Mean_Temp = round(temp_mean, 1),
  Max_Temp  = temp_max
)
print(temp_summary)

# %%
# ============================================================
# Part c: dplyr summaries per month
# ============================================================
library(dplyr)

cat("=== Part c: dplyr Summaries per Month ===\n")

dplyr_summary <- airquality %>%
  group_by(Month) %>%
  summarise(
    Mean_Ozone = round(mean(Ozone, na.rm = TRUE), 1),
    Max_Wind   = max(Wind,  na.rm = TRUE),
    Min_Temp   = min(Temp,  na.rm = TRUE),
    Mean_Temp  = round(mean(Temp, na.rm = TRUE), 1),
    Max_Temp   = max(Temp,  na.rm = TRUE),
    .groups = "drop"
  )

print(dplyr_summary)

# %%
# ============================================================
# Part d: Add Temp_category column
# ============================================================
cat("=== Part d: Add Temp_category Column ===\n")

airquality <- airquality %>%
  mutate(Temp_category = case_when(
    Temp < 70              ~ "Cool",
    Temp >= 70 & Temp < 80 ~ "Mild",
    Temp >= 80             ~ "Hot"
  ))

cat("Sample rows with Temp_category:\n")
print(head(airquality[, c("Month", "Day", "Temp", "Temp_category")], 10))

# %%
# ============================================================
# Part e: Count days in each temperature category per month
# ============================================================
cat("=== Part e: Days per Temperature Category per Month ===\n")

temp_category_count <- airquality %>%
  group_by(Month, Temp_category) %>%
  summarise(Days = n(), .groups = "drop")

print(temp_category_count)

# %%
# ============================================================
# Part f: Clean monthly summary table
# ============================================================
cat("=== Part f: Clean Monthly Summary Table ===\n")

# Find prevailing temperature category per month
prevailing_temp <- airquality %>%
  group_by(Month, Temp_category) %>%
  summarise(Days = n(), .groups = "drop") %>%
  group_by(Month) %>%
  slice_max(Days, n = 1, with_ties = FALSE) %>%
  select(Month, Prevailing_Temp_Category = Temp_category)

# Build the clean summary
clean_summary <- airquality %>%
  group_by(Month) %>%
  summarise(
    N_Observations = n(),
    Avg_Ozone      = round(mean(Ozone,   na.rm = TRUE), 1),
    Avg_Solar.R    = round(mean(Solar.R, na.rm = TRUE), 1),
    Avg_Wind       = round(mean(Wind,    na.rm = TRUE), 1),
    Avg_Temp       = round(mean(Temp,    na.rm = TRUE), 1),
    .groups = "drop"
  ) %>%
  left_join(prevailing_temp, by = "Month")

print(clean_summary)

# %%
# ============================================================
# Part g: Add cumulative_heat column (cumulative sum of Temp per month)
# ============================================================
cat("=== Part g: Add cumulative_heat Column ===\n")

airquality <- airquality %>%
  group_by(Month) %>%
  mutate(cumulative_heat = cumsum(Temp)) %>%
  ungroup()

cat("Sample rows for Month 5 showing cumulative_heat:\n")
print(
  airquality[, c("Month", "Day", "Temp", "cumulative_heat")] %>%
    filter(Month == 5) %>%
    head(10)
)
